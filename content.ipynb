# %% [markdown]
# <h1 align="center" style="color: #cd7f32;"> CS440 Quantum Programming II </h2>

# %% [markdown]
# <h2 align="left" style="color: #cd7f32;"> Content </h2>

# %% [markdown]
# ### Grover's Search for Max-Cut problem

# %% [markdown]
# [Grover's Algorithm revisited](grover/01_grover_algorithm_revisited.ipynb)
#
# [Max-Cut problem](grover/02_max_cut_problem.ipynb) | [Adders and numbers checking](grover/03_adders_and_numbers_checking.ipynb) | [Grover's Algorithm for Max-Cut problem](grover/04_grover_algorithm_for_max-cut_problem.ipynb)

# %% [markdown]
# ### VQE
#
# [Variational quantum algorithms](vqe/01_variational_quantum_algorithms.ipynb)
#
# [Variational quantum eigensolver: basics and motivation](vqe/02_variational_quantum_eigensolver_basics.ipynb) |
# [Variational principle](vqe/03_variational_principle.ipynb) |
# [Variational quantum eigensolver: implementation](vqe/04_variational_quantum_eigensolver_implementation.ipynb)

# %% [markdown]
# ### QUBO Formulation
#
# [Combinatorial optimization problems](qubo/01_cop.ipynb)
#
# [QUBO mathematical definition](qubo/02_qubo_definition.ipynb) | [Max-Cut Problem](qubo/03_qubo_examples_maxcut.ipynb)
#
# [Penalty Method](qubo/04_qubo_penalty_method.ipynb) &nbsp;|&nbsp;
# [Travelling Salesman Problem](qubo/05_qubo_examples_tsp.ipynb) &nbsp;|&nbsp;
# [Graph Coloring](qubo/06_qubo_examples_graph_coloring.ipynb)
#
# [Higher Order Models](qubo/07_hubo.ipynb)

# %% [markdown]
# ### Adiabatic Quantum Computing and Quantum Annealing

# %% [markdown]
# [Continous time evolution](aqc/01_continuous_time_evolution.ipynb)
#
# [Adiabatic quantum computing](aqc/02_adiabatic_quantum_computing.ipynb)
#
# [Ising model](aqc/03_ising_model.ipynb) | [Ising model to QUBO](aqc/04_ising_model_to_qubo.ipynb)
